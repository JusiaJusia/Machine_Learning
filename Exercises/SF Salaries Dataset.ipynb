# %% [markdown]
# ### SF Salaries Dataset

# %% [markdown]
# https://www.kaggle.com/kaggle/sf-salaries?select=Salaries.csv

# %%
import pandas as pd

# %%
sal=pd.DataFrame(pd.read_csv('Salaries.csv'))

# %%
sal.head(5)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %%
sal.sort[sal['EmployeeName']=='JOSEPH DRISCOLL']
# Out:
#     Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 24  31909.28       NaN  270324.91         270324.91  2011    NaN
#
#            Agency  Status
# 24  San Francisco     NaN

# %%
sal.sort_values('TotalPayBenefits', ascending=False)
# Out:
#             Id          EmployeeName  \
# 0            1        NATHANIEL FORD
# 1            2          GARY JIMENEZ
# 110531  110532           David Shinn
# 110532  110533            Amy P Hart
# 110533  110534  William J Coaker Jr.
# ...        ...                   ...
# 148634  148635        David M Turner
# 110528  110529      Timothy E Gibson
# 110529  110530        Mark E Laherty
# 110530  110531         David P Kucia
# 148653  148654             Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 110531                                  Deputy Chief 3  129150.01
# 110532                               Asst Med Examiner  318835.49
# 110533                        Chief Investment Officer  257340.00
# ...                                                ...        ...
# ...

# %%
sal.sort_values('TotalPayBenefits', ascending=True)
# Out:
#             Id          EmployeeName  \
# 148653  148654             Joe Lopez
# 110530  110531         David P Kucia
# 110529  110530        Mark E Laherty
# 110528  110529      Timothy E Gibson
# 148633  148634      Edward Ferdinand
# ...        ...                   ...
# 110533  110534  William J Coaker Jr.
# 110532  110533            Amy P Hart
# 110531  110532           David Shinn
# 1            2          GARY JIMENEZ
# 0            1        NATHANIEL FORD
#
#                                               JobTitle    BasePay  \
# 148653                      Counselor, Log Cabin Ranch       0.00
# 110530                                Police Officer 3        NaN
# 110529                                Police Officer 3        NaN
# 110528                                Police Officer 3        NaN
# 148633                                 General Laborer       0.00
# ...                                                ...        ...
# ...

# %%
sal.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %%
sal.groupby('JobTitle').count().sort_values('Id',ascending=False)
# Out:
#                                                       Id  EmployeeName  \
# JobTitle
# Transit Operator                                    7036          7036
# Special Nurse                                       4389          4389
# Registered Nurse                                    3736          3736
# Public Svc Aide-Public Works                        2518          2518
# Police Officer 3                                    2421          2421
# ...                                                  ...           ...
# BUILDING SERVICES TECHNICIAN                           1             1
# Public Service Aide-Technical                          1             1
# Public Safety Comm Tech                                1             1
# CAPTAIN, BUREAU OF FIRE PREVENTION AND PUBLIC SAFE     1             1
# ZOO CURATOR                                            1             1
#
#                                                     BasePay  OvertimePay  \
# JobTitle
# ...

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
sum(sal[sal['Year']==2013]['JobTitle'].value_counts()==1)
# Out:
# 202
